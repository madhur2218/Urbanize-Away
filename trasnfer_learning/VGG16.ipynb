# %%
# import the libraries as shown below
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
#from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
#import splitfolders

# %%
#input_folders= r"C:\Users\madhu\Desktop\Skin burn project\dataset"

# %%
#splitfolders.ratio(input_folders,output='dataset1',seed=50,ratio=(.8,.1,.1), group_prefix=None)

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    r"dataset1\train",
    seed=123,
    shuffle=True,
    image_size=(224,224),
    batch_size=32
)
# Out:
# Found 1351 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Degree1', 'Degree2', 'Degree3', 'healthy']

# %%
for image_batch, labels_batch in dataset.take(5):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 224, 224, 3)
# [1 0 3 2 3 1 0 0 1 0 1 1 3 0 1 0 3 3 3 3 0 3 3 1 0 3 0 1 0 2 3 3]
# (32, 224, 224, 3)
# [0 3 3 3 2 0 0 0 0 3 3 1 0 3 3 1 0 0 0 0 3 0 0 1 0 1 0 3 0 0 2 1]
# (32, 224, 224, 3)
# [1 0 0 1 1 1 0 1 3 0 3 1 0 3 0 3 1 1 1 0 1 3 1 3 0 2 1 0 1 1 3 3]
# (32, 224, 224, 3)
# [1 0 0 3 0 0 0 0 0 1 3 3 1 1 1 3 1 1 3 1 0 1 1 3 0 1 1 3 1 0 0 3]
# (32, 224, 224, 3)
# [1 0 0 0 0 0 1 3 1 2 2 1 0 1 0 1 2 3 3 3 3 3 3 0 0 3 1 2 3 1 0 0]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(5):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

# %%
train_path =  r"C:\Users\madhu\Desktop\Skin burn project\dataset1\train"
valid_path =  r"C:\Users\madhu\Desktop\Skin burn project\dataset1\val"

# %%
# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# don't train existing weights
for layer in vgg.layers:
    layer.trainable = False

# %%
# our layers - you can add more if you want
x = Flatten()(vgg.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(4, activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4)                 100356
#
# =================================================================
# Total params: 14,815,044
# Trainable params: 100,356
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='sparse_categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   rotation_range=10,
                                   horizontal_flip = True)

# %%
validation_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range = 0.3,
        zoom_range = 0.2,
        rotation_range=10,
        horizontal_flip=True)

validation_generator = validation_datagen.flow_from_directory(
        r"C:\Users\madhu\Desktop\Skin burn project\dataset1\val",
        target_size=(224,224),
        batch_size=32,
        class_mode="sparse"
)
# Out:
# Found 168 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(r"C:\Users\madhu\Desktop\Skin burn project\dataset1\train",
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')

test_set = test_datagen.flow_from_directory(r"C:\Users\madhu\Desktop\Skin burn project\dataset1\test",
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'sparse')
# Out:
# Found 1351 images belonging to 4 classes.
# Found 171 images belonging to 4 classes.

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/20
# 43/43 [==============================] - 102s 2s/step - loss: 0.8173 - accuracy: 0.6743 - val_loss: 0.5913 - val_accuracy: 0.7310
# Epoch 2/20
# 43/43 [==============================] - 100s 2s/step - loss: 0.5435 - accuracy: 0.7654 - val_loss: 0.6327 - val_accuracy: 0.7485
# Epoch 3/20
# 43/43 [==============================] - 104s 2s/step - loss: 0.4443 - accuracy: 0.8001 - val_loss: 0.5183 - val_accuracy: 0.7485
# Epoch 4/20
# 43/43 [==============================] - 112s 3s/step - loss: 0.3645 - accuracy: 0.8468 - val_loss: 0.7124 - val_accuracy: 0.7018
# Epoch 5/20
# 43/43 [==============================] - 116s 3s/step - loss: 0.3565 - accuracy: 0.8542 - val_loss: 0.5530 - val_accuracy: 0.7719
# Epoch 6/20
# 43/43 [==============================] - 125s 3s/step - loss: 0.2769 - accuracy: 0.8905 - val_loss: 0.5196 - val_accuracy: 0.7895
# Epoch 7/20
# 43/43 [==============================] - 110s 3s/step - loss: 0.2705 - accuracy: 0.8882 - val_loss: 0.6336 - val_accuracy: 0.7368
# Epoch 8/20
# 43/43 [==============================] - 105s 2s/step - loss: 0.2982 - accuracy: 0.8808 - val_loss: 0.6357 - val_accuracy: 0.7719
# Epoch 9/20
# 43/43 [==============================] - 106s 2s/step - loss: 0.2684 - accuracy: 0.8875 - val_loss: 0.5341 - val_accuracy: 0.7953
# Epoch 10/20
# 43/43 [==============================] - 101s 2s/step - loss: 0.2306 - accuracy: 0.9067 - val_loss: 0.5170 - val_accuracy: 0.8246
# Epoch 11/20
# 43/43 [==============================] - 112s 3s/step - loss: 0.1933 - accuracy: 0.9297 - val_loss: 0.5235 - val_accuracy: 0.8129
# Epoch 12/20
# 43/43 [==============================] - 112s 3s/step - loss: 0.1848 - accuracy: 0.9297 - val_loss: 0.5293 - val_accuracy: 0.8187
# Epoch 13/20
# 43/43 [==============================] - 105s 2s/step - loss: 0.1607 - accuracy: 0.9452 - val_loss: 0.5865 - val_accuracy: 0.7778
# Epoch 14/20
# 43/43 [==============================] - 102s 2s/step - loss: 0.1508 - accuracy: 0.9504 - val_loss: 0.5222 - val_accuracy: 0.7836
# Epoch 15/20
# 43/43 [==============================] - 103s 2s/step - loss: 0.1721 - accuracy: 0.9400 - val_loss: 0.6595 - val_accuracy: 0.7602
# Epoch 16/20
# 43/43 [==============================] - 101s 2s/step - loss: 0.1873 - accuracy: 0.9312 - val_loss: 0.6178 - val_accuracy: 0.7602
# Epoch 17/20
# 43/43 [==============================] - 101s 2s/step - loss: 0.1756 - accuracy: 0.9334 - val_loss: 0.5860 - val_accuracy: 0.7953
# Epoch 18/20
# 43/43 [==============================] - 101s 2s/step - loss: 0.1484 - accuracy: 0.9534 - val_loss: 0.5663 - val_accuracy: 0.7953
# Epoch 19/20
# 43/43 [==============================] - 100s 2s/step - loss: 0.1399 - accuracy: 0.9489 - val_loss: 0.5938 - val_accuracy: 0.8070
# Epoch 20/20
# 43/43 [==============================] - 100s 2s/step - loss: 0.1849 - accuracy: 0.9260 - val_loss: 0.5879 - val_accuracy: 0.8304

# %%
scores = model.evaluate(test_set)
# Out:
# 6/6 [==============================] - 11s 2s/step - loss: 0.5879 - accuracy: 0.8304

# %%
acc = r.history['accuracy']
val_acc = r.history['val_accuracy']

loss = r.history['loss']
val_loss = r.history['val_loss']

# %%
EPOCHS=20
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(17, 17))
for images, labels in test_set:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
    break
# Out:
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
